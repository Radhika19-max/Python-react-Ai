# %%
numbers = [12, 25, 8, 43, 67, 90, 15, 22, 34, 56, 78, 11, 29, 40, 5]

total = sum(numbers)

average = total / len(numbers)

largest = max(numbers)
smallest = min(numbers)

even_count = 0
odd_count = 0

for num in numbers:
    if num % 2 == 0:
        even_count += 1
    else:
        odd_count += 1

print("List:", numbers)
print("Total sum = ", total)
print("Average =", average)
print("Largest number =", largest)
print("Smallest number =", smallest)
print("Even numbers =", even_count)
print("Odd Numbers =", odd_count)
# Out:
# List: [12, 25, 8, 43, 67, 90, 15, 22, 34, 56, 78, 11, 29, 40, 5]
# Total sum =  535
# Average = 35.666666666666664
# Largest number = 90
# Smallest number = 5
# Even numbers = 8
# Odd Numbers = 7

# %%
First  = [10, 11, 102, [1, 2], [3, 4, 5],[6, 7]]

print("Number =", First[4][2])
# Out:
# Number = 5

# %%
inventory = ["Laptop", "Mouse", "Monitor", "Keyboard"]
target = "Tablet"

if target in inventory:
    print(target, "is available in inventory.")
else:
    print(target, "is not available in inventory.")
# Out:
# Tablet is not available in inventory.

# %%
number = [5, 20, 15, 20, 25, 50, 20]

item = 20

while item in numbers:
    numbers.remove(item)

print("Updated List:", numbers)
# Out:
# Updated List: [12, 25, 8, 43, 67, 90, 15, 22, 34, 56, 78, 11, 29, 40, 5]

# %%
keys = ["name", "age", "city"]
values = ["ABC", 25, "Jaipur"]

student = dict(zip(keys, values))

print(student)
# Out:
# {'name': 'ABC', 'age': 25, 'city': 'Jaipur'}

# %%
person = {
    "name": "ABC",
    "address": {
        "city": "Jaipur",
        "state": "Rajasthan"
    }
}

city = person["address"]["city"]

print("city =", city)
# Out:
# city = Jaipur
