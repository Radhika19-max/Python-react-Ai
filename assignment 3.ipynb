# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

m1 = float(input("Enter marks of subject 1: "))
m2 = float(input("Enter marks of subject 2: "))
m3 = float(input("Enter marks of subject 3: "))
m4 = float(input("Enter marks of subject 4: "))
m5 = float(input("Enter marks of subject 5: "))

total = m1 + m2 + m3 + m4 + m5
percentage = (total/500) * 100

if percentage >= 60:
    grade = 'A'

elif percentage >= 50:
    grade = 'B'

elif percentage >= 40:
    grade = 'c'

elif percentage >=33:
    grade = 'D'

else:
    grade = 'Fail'

print("\n----RESULT-----")
print("Name       :", name)
print("class      :", student_class)
print("Total Marks:", total)
print("Percentage :", percentage, "%")
print("Grade      :", grade)
# Out:
# ----RESULT-----
# Name       : Ram
# class      : 10
# Total Marks: 320.0
# Percentage : 64.0 %
# Grade      : A

# %%
num = int(input("Enter a number between 2 and 50: "))

if num<2 or num > 50:
    print ("Invalid Input ! Please enter a number between 2 and 50.")
else:
    print(f"|nMultiplication Table of {num}")
    print("-" * 25)

    for i in range(1, 11):
        print(f"{num:2} * {i:2} = {num*i:3}")
# Out:
# |nMultiplication Table of 23
# -------------------------
# 23 *  1 =  23
# 23 *  2 =  46
# 23 *  3 =  69
# 23 *  4 =  92
# 23 *  5 = 115
# 23 *  6 = 138
# 23 *  7 = 161
# 23 *  8 = 184
# 23 *  9 = 207
# 23 * 10 = 230

# %%
num = int(input("Enter a number: "))

original = num
reverse = 0

while num>0:
    digit = num % 10
    reverse = reverse *10 + digit 
    num = num // 10

print("Reverse Number:", reverse)

if original == reverse:
    print("Plaindrome Number")
else:
    print("Not a Plaindrome Number")
# Out:
# Reverse Number: 12321
# Plaindrome Number
