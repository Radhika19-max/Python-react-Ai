# %%
name = input("Enter student name: ")
student_class = input("Enter class: ")

m1 = float(input("Enter marks of maths: "))
m2 = float(input("Enter marks of english: "))
m3 = float(input("Enter marks of science: "))
m4 = float(input("Enter marks of socail science: "))
m5 = float(input("Enter marks of computer: "))

total = m1 + m2 + m3 + m4 +m5
percentage = total / 5

print("\n-----RESULT-----")
print("Name :", name)
print("class :", student_class)
print("Total marks :", total)
print("Percentage :", percentage,"%")
# Out:
# -----RESULT-----
# Name : Radhika
# class : 10
# Total marks : 376.0
# Percentage : 75.2 %

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

result = str1 + str2

print("\nConcatenated string:", result)

print("lower()    :", result.lower())
print("upper()     :", result.upper())
print("title()    :", result.title())
print("swapcase()   :", result.swapcase())
print("capitalize()   :", result.capitalize())
print("casefold()   :", result.casefold())
print("center(30)   :", result.center(30))
print("count('a')    :", result.count('a'))
print("find('a')    :", result.find('a'))
print("isalnum()   :", result.isalnum())
print("isdigit()   :", result.isdigit())
print("isnumeric()   :", result.isnumeric())
print("isspace()   :", result.isspace())
print("replace('a','@') :", result.replace('a','@'))
# Out:
# Concatenated string: hello world
# lower()    : hello world
# upper()     : HELLO WORLD
# title()    : Hello World
# swapcase()   : HELLO WORLD
# capitalize()   : Hello world
# casefold()   : hello world
# center(30)   :          hello world
# count('a')    : 0
# find('a')    : -1
# isalnum()   : False
# isdigit()   : False
# isnumeric()   : False
# isspace()   : False
# replace('a','@') : hello world

# %%
a = 10
print("Initial value of a =", a)

a += 5
print("After += 5 :", a)

a -= 3
print("After -= 3 :", a)

a *= 2
print("After *= 2 :", a)

a /= 4
print("After /= 4 :", a)

a //= 2 
print("After //= 2 :", a)

a %= 3 
print("After %= 3 :", a)

a **= 2
print("After **= 2 :", a)
# Out:
# Initial value of a = 10
# After += 5 : 15
# After -= 3 : 12
# After *= 2 : 24
# After /= 4 : 6.0
# After //= 2 : 3.0
# After %= 3 : 0.0
# After **= 2 : 0.0
