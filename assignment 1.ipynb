# %%
name = "Radhika"
age = 19 
print("Name:", name ,"Age:", age)

print("january", "feburary", "march", sep=" | ")

print("Hello", end=" ")
print("Radhika")
# Out:
# Name: Radhika Age: 19
# january | feburary | march
# Hello Radhika

# %%
name = input("Enter your name: ")
print("Hello,",name + "!Welcome.")
# Out:
# Hello, Radhika!Welcome.
